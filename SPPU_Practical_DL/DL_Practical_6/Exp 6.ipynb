# %% [markdown]
# Name: Sonal Shinde
# Division: C
# Roll no. 38

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Parameters
max_features = 10000
maxlen = 100
batch_size = 32

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# %%
# Pad sequences
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
# Build model (Improved with Bidirectional LSTM)
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.2)))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train
model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=5,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 309s 368ms/step - accuracy: 0.7185 - loss: 0.5372 - val_accuracy: 0.8327 - val_loss: 0.3936
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 305s 390ms/step - accuracy: 0.8697 - loss: 0.3284 - val_accuracy: 0.8454 - val_loss: 0.3600
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 301s 385ms/step - accuracy: 0.8999 - loss: 0.2593 - val_accuracy: 0.8277 - val_loss: 0.4080
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 267s 313ms/step - accuracy: 0.9174 - loss: 0.2103 - val_accuracy: 0.8436 - val_loss: 0.4079
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 212s 271ms/step - accuracy: 0.9374 - loss: 0.1687 - val_accuracy: 0.8380 - val_loss: 0.4374

# %%
# Evaluate
score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)

print(f'Test score: {score}')
print(f'Test accuracy: {acc}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8351 - loss: 0.4449
# Test score: 0.4374163746833801
# Test accuracy: 0.8380399942398071
